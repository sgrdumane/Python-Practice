# %% [markdown]
# # Learning Basics

# %% [markdown]
# ### Solve these questions using python

# %%
a= ("hello")

# %%
a
# Out:
# 'hello'

# %% [markdown]
# Q1.  A man walks 25 km in 6 hours. Find the speed of the man?
#
# Solution:
# Distance traveled = 25 km
# Time taken to travel = 6 hours
# Speed of Man = Distance traveled/Time taken
# = 25km/6hr
# = 4.16 km/hr
# Therefore, a man travels at a speed of 4.16 km/hr

# %%
# Answer
man = "Vipul"
km = 25
time = 6
speed= km/time

# %%
print(round(4.51))
# Out:
# 5

# %%
print(f"The man {man} travelled with a speed {round(speed,2)}km per hour")
# Out:
# The man Vipul travelled with a speed 4.17km per hour

# %%
print("The man ",man,"travelled with a speed ",round(speed,2),"km per hour")
# Out:
# The man  Vipul travelled with a speed  4.17 km per hour

# %%
data = f"The man {man} travelled with a speed {round(speed,2)}km per hour"

# %%
data
# Out:
# 'The man Vipul travelled with a speed 4.17km per hour'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write your python script here
x = 1.52098232
y = 1.47098290
z= 10**8

avg = (x*z + y*z) /2

print(f"the average distance between earth adn sun is {avg} km")
# Out:
# the average distance between earth adn sun is 149598261.0 km

# %% [markdown]
# Q3. A car moves from A to B at a speed of 70 km/hr and comes back from B to A at a speed of 40 km/hr. Find its average speed during the journey?
#
# Solution:
# Since the distance traveled is the same the Average Speed= (x+y)/2 where x, y are two different speeds
# Substitute the Speeds in the given formula
# Average Speed = (70+40)/2
# = 110/2
# = 55 km/hr
# The Average Speed of the Car is 55 km/hr

# %%
# Write your python script here
S1 = 70
S2 = 40

average_speed = (S1+S2)/2
print (f"The Average Speed of the Car is {average_speed} km/hr")
# Out:
# The Average Speed of the Car is 55.0 km/hr

# %% [markdown]
# Q4. A bus covers a certain distance in 45 minutes if it runs at a speed of 50 km/hr. What must be the speed of the bus in order to reduce the time of journey by 20 minutes?
#
# Solution:
# Speed = Distance/Time
# 50 = x/3/4
# 50 = 4x/3
# 4x = 150
# x = 150/4
# = 37.5 km
#
# Now by applying the same formula we can find the speed
#
# Now, time = 40 mins or 0.66 hr since the journey is reduced by 20 mins
#
# S = Distance/Time
# = 37.5/0.66
# = 56.81 km/hr

# %%
# Write your python script here
Speed = 50 
time = 3/4
distance = time*Speed
print (distance)
# Out:
# 37.5

# %%
Time2 = 0.66

# %%
Speed2  =distance/Time2

# %%
print(f"The speed of the bus in order to reduce the time of journey by 20 minutes is {round(Speed2,2)} km/hr")
# Out:
# The speed of the bus in order to reduce the time of journey by 20 minutes is 56.82 km/hr

# %% [markdown]
# Q5. Ram traveled 200 km in 3 hours by train and then traveled 140 km in 3 hours by car and 5 km in 1/2 hour by cycle. What is the average speed during the whole journey?
#
# Solution:
# Distance traveled by Train is 200 km in 3 hours
# Distance Traveled by Car is 140 km in 3 hours
# Distance Traveled by Cycle is 5 km in 1/2 hour
# Average Speed = Total Distance/Total Time
# = (200+140+5)/(3+3+1/2)
# = 345/6 1/2
# = 345/(13/2)”
# = 345*2/13
# = 53.07 km/hr

# %%
# Write your python script here
Distance_Train= 200
Time_train = 3
Distance_Car= 140
Time_Car = 3
Distance_Cycle= 5
Time_Cycle = 0.5

# %%
Average_Speed = (Distance_Train+Distance_Car+Distance_Cycle)/(Time_train+Time_Car+Time_Cycle)

# %%
print(f"the average speed during the whole journey is {Average_Speed} km/hr")
# Out:
# the average speed during the whole journey is 53.07692307692308 km/hr

# %% [markdown]
# Q6. A train covers 150 km in 3 hours. Find its speed?
#
# Solution:
# Speed = Distance/Time
# = 150 km/3 hr
# = 50 km/hr
# Therefore, Speed of the Train is 50 km/hr.

# %%
# Write your python script here
Distance = 150
time = 3
speed = Distance/time
print(f"Speed of the Train is {speed} km/hr")
# Out:
# Speed of the Train is 50.0 km/hr

# %% [markdown]
# Q7. A car covers a distance of 420 m in 1 minute whereas a train covers 70 km in 30 minutes. Find the ratio of their speeds?
#
# Solution:
# Speed of the Car = Distance Traveled/Time Taken
# = 420m/60 sec
# = 7 m/sec
#
# Speed of the Train = Distance Traveled/Time Taken
# = 70 km/1/2 hr
# = 140 km/hr
#
# To convert it into m/sec multiply with 5/18
# = 140*5/18
# = 38.8 m/sec
# = 39 m/sec (Approx)
# Ratio of Speeds = 7:39

# %%
# Write your python script here
distance_c = 420
time_c = 60
speed_c = round((distance_c/time_c))
print (speed_c)
# Out:
# 7

# %%
distance_t = 70
time_t = 0.5
speed_t = round((distance_t/time_t)*5/18)
print (speed_t)
# Out:
# 39

# %%
print(f"Ratio of Speeds is {speed_c}:{speed_t}")
# Out:
# Ratio of Speeds is 7:39
